# %% [markdown]
# ### Introduction to streamlit
#
# Streamlit is an open-sourde app framework for machine learning and data science projects. It allows us to create beautiful web applications for our ML and DS projects with simple python scripts.
