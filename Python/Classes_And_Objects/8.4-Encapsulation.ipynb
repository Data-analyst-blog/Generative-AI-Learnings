# %% [markdown]
# ## Encapsulation and Abstraction
#
# Encapsulation and abstraction are two funadmental principles of Oject-Oriented Programming (OOP) that help in designinging robust, maintainable and reusable code. Enacpsulation involves bundling data and methods that operate on the data within a single unit, while abstraction involves hiding complex implementation details and exposing only the necessary features.

# %% [markdown]
# ## Encapsulation
#
# Encapsulation is the concept of wrapping data (variables) and methods (functions) together as a single unit. it restricts direct access to some of the object's components, which is a means of preventing accidental interference and missuse of the data.

# %%
## encasuplation with Getter and Setter Methods
## Public, Protected, private variables or access modifiers

class Person:
    def __init__(self, name, age):
        self.name = name   # public variables
        self.age = age.    # public variables

def get_name(person):
    return person.name

person = Person('Yash',34)
get_name(person)
# Out:
# 'Yash'

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class Person:
    def __init__(self, name, age):
        self.name = name   # public variables
        self.__age = age    # private variables

# %%
person = Person('Yashwanth',34)
dir(person)
# Out:
# ['_Person__age',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'name']

# %%
def get_age(person):
    return person._Person__age

get_age(person)
# Out:
# 34

# %%
class Person:
    def __init__(self, name, age, gender):
        self.name = name   # public variables
        self.__age = age    # private variables
        self._gender = gender  # protected variables

def get_gender(person):
    return person.gender

person = Person('Yashwanth', 34, 'Male')
person.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 11
#       8     return person.gender
#      10 person = Person('Yashwanth', 34, 'Male')
# ---> 11 person.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %%
class Person:
    def __init__(self, name, age, gender):
        self.name = name   # public variables
        self.__age = age    # private variables
        self._gender = gender  # protected variables

class Employee(Person):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)


employee = Employee('Yashwanth', 34, 'Male')
print(employee._gender)
# Out:
# Male

# %%
## Encapsulation with Getter and Setter methods

class Person:
    def __init__(self, name, age):
        self.__name = name ## Private access modifier or variable
        self.__age = age ## Private variavles

    ## getter method for name
    def get_name(self):
        return self.__name

    ## Setter method for name
    def set_name(self,name):
        self.__name = name
        return self.__name

    ## getter method for name
    def get_age(self):
        return self.__age

    ## Setter method for name
    def set_age(self,age):
        if age > 0:
            self.__age = age
            return self.__age
        else:
            return "Age cannot be negative"

person = Person("Yash", 34)

## Access and modify private variables using getter and setter

print(person.get_name())
print(person.get_age())

print(person.set_name('Yashas'))
print(person.set_age(-5))
# Out:
# Yash
# 34
# Yashas
# Age cannot be negative
